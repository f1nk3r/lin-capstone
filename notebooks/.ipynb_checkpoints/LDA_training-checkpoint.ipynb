# %%
import pandas as pd
from gensim.test.utils import common_texts
from gensim.corpora.dictionary import Dictionary

# %%
# Count number of users in each pronoun group
group_counts = people["Pronouns"].value_counts()

# Create a probability table (normalized by group size)
pronoun_table = pd.crosstab(
    people["Pronouns"],
    people["Pronouns"],
    normalize="index"
)

pronoun_table
